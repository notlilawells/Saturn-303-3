# %%
import pandas as pd
import numpy as np

# %%
red = pd.read_csv('Data/winequality-red.csv', delimiter=";")
white = pd.read_csv('Data/winequality-white.csv', delimiter=";")

# %%
red['type'] = 'red'
white['type'] = 'white'

# %%
all_df = pd.concat([red, white], ignore_index = True)

# %%
print(all_df.shape)
print(all_df.isnull().sum().sum())
all_df.head()
# Out:
# (6497, 13)
# 0
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality type
# 0      9.4        5  red
# 1      9.8        5  red
# 2      9.8        5  red
# 3      9.8        6  red
# 4      9.4        5  red

# %%
all_df.to_csv('winequaltiy-all.csv')

# %%
np.std(all_df.quality.values)
# Out:
# 0.8731880644450568

# %% [markdown]
# # Visualizing Distributions

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.kdeplot(all_df['quality'], shade=True)
plt.title('Distribution of Response Variable (Quality)')
plt.xlabel('Quality')
plt.xticks(range(1, 11))
plt.show()
# Out:
# /var/folders/25/jjvj1r3d1lj4q97f1twwhgkm0000gn/T/ipykernel_30886/2450911574.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(all_df['quality'], shade=True)

# %%
X_test = pd.read_csv('data/X_test.csv')
X_train = pd.read_csv('data/X_train.csv')
y_test = pd.read_csv('data/y_test.csv')
y_train = pd.read_csv('data/y_train.csv')

# %%
all_df.corrwith(all_df.quality).sort_values()
# Out:
# density                -0.305858
# volatile acidity       -0.265699
# chlorides              -0.200666
# fixed acidity          -0.076743
# total sulfur dioxide   -0.041385
# residual sugar         -0.036980
# pH                      0.019506
# sulphates               0.038485
# free sulfur dioxide     0.055463
# citric acid             0.085532
# alcohol                 0.444319
# quality                 1.000000
# dtype: float64

# %%
sns.pairplot(data = all_df)

# %%
# Defining function to make exploratory plots
def plot_dist(var):
    fig, axes = plt.subplots(1,3, figsize = (12, 3))
    plt.subplots_adjust(wspace = 0.2)

    sns.histplot(x = var, data = all_df, ax = axes[0])
    sns.regplot(x = var, y = "quality", data = all_df, ax = axes[1])
    sns.barplot(x = "quality", y = var, data = all_df, ax = axes[2])

# %%
plot_dist("density")

# %%
plot_dist("volatile acidity")

# %%
plot_dist("alcohol")

# %%
plot_dist("citric acid")

# %%
plot_dist("pH")

# %%
plot_dist("chlorides")

# %%
plot_dist("fixed acidity")

# %%
plot_dist("total sulfur dioxide")

# %%
plot_dist("sulphates")

# %%
plot_dist("residual sugar")

# %%
plot_dist("free sulfur dioxide")
