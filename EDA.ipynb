# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error

# %%
red = pd.read_csv('Data/winequality-red.csv', delimiter=";")
white = pd.read_csv('Data/winequality-white.csv', delimiter=";")
red['type'] = 'red'
white['type'] = 'white'

# %%
all_df = pd.concat([red, white], ignore_index = True)
all_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality type
# 0      9.4        5  red
# 1      9.8        5  red
# ...

# %%
all_df.to_csv('winequality-all.csv')

# %%
np.std(all_df.quality.values)
# Out:
# 0.8731880644450568

# %%
np.mean(all_df.quality)
# Out:
# 5.818377712790519

# %%
all_df = pd.read_csv('winequality-all.csv')
all_df.drop(columns = "Unnamed: 0", inplace = True)

# %%
all_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
all_df.describe(include = 'object')
# Out:
#          type
# count    6497
# unique      2
# top     white
# freq     4898

# %%
all_df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# type                    0
# dtype: int64

# %%
# Percent wines that are white
4898/len(all_df.type)
# Out:
# 0.7538864091118977

# %% [markdown]
# # Visualizing Distributions

# %%
print((np.mean(y_test) + np.mean(y_train))/2)
# Out:
# quality    5.809469
# dtype: float64

# %%
X_test = pd.read_csv('data/X_test.csv')
X_train = pd.read_csv('data/X_train.csv')
y_test = pd.read_csv('data/y_test.csv')
y_train = pd.read_csv('data/y_train.csv')

# %%
all_df.corrwith(all_df.quality).sort_values()
# Out:
# density                -0.305858
# volatile acidity       -0.265699
# chlorides              -0.200666
# fixed acidity          -0.076743
# total sulfur dioxide   -0.041385
# residual sugar         -0.036980
# pH                      0.019506
# sulphates               0.038485
# free sulfur dioxide     0.055463
# citric acid             0.085532
# alcohol                 0.444319
# quality                 1.000000
# dtype: float64

# %%
sns.pairplot(data = all_df)

# %%
# Defining function to make exploratory plots
def plot_dist(var):
    fig, axes = plt.subplots(1,2, figsize = (10, 4))
    plt.subplots_adjust(wspace = 0.2)

    sns.histplot(x = var, data = all_df, ax = axes[0])
    # sns.regplot(x = var, y = "quality", data = all_df, ax = axes[1])
    sns.barplot(x = "quality", y = var, data = all_df, ax = axes[1])

# %%
plot_dist("density")

# %%
plot_dist("volatile acidity")

# %%
plot_dist("alcohol")

# %%
plot_dist("citric acid")

# %%
plot_dist("pH")

# %%
plot_dist("chlorides")

# %%
plot_dist("fixed acidity")

# %%
plot_dist("total sulfur dioxide")

# %%
plot_dist("sulphates")

# %%
plot_dist("residual sugar")

# %%
plot_dist("free sulfur dioxide")

# %%
# %matplotlib notebook

# %%
plt.hist(red.quality.values, bins = np.arange(1,10), color = 'r', alpha = 0.8, zorder = 5,  label = 'red')
plt.title('Wine Quality Distribution', fontsize=14)
plt.hist(white.quality.values, bins = np.arange(1,10), color = 'grey', alpha = 0.5, label = 'white')
plt.legend()
plt.xlabel('Wine Quality', fontsize=14)
plt.ylabel('Count', fontsize=14);
#plt.yscale('log')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
scaled_df = pd.read_csv('Data/winequality_all_scaled.csv', index_col = 0)
scaled_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.297521          0.413333     0.000000        0.019939   0.111296
# 1       0.330579          0.533333     0.000000        0.030675   0.147841
# 2       0.330579          0.453333     0.024096        0.026074   0.137874
# 3       0.611570          0.133333     0.337349        0.019939   0.109635
# 4       0.297521          0.413333     0.000000        0.019939   0.111296
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.034722              0.064516  0.206092  0.612403   0.191011
# 1             0.083333              0.140553  0.186813  0.372093   0.258427
# 2             0.048611              0.110599  0.190669  0.418605   0.241573
# 3             0.055556              0.124424  0.209948  0.341085   0.202247
# 4             0.034722              0.064516  0.206092  0.612403   0.191011
#
#     alcohol  type_red  type_white
# ...

# %%
# %matplotlib inline
sns.set_style('ticks')

# %%
fig, axes = plt.subplots(3, 4, figsize = (16, 12))
plt.subplots_adjust(wspace = 0.3)
axes[0][0].hist(scaled_df['fixed acidity'], bins = 15)
axes[0][1].hist(scaled_df['volatile acidity'], bins = 15)
axes[0][2].hist(scaled_df['citric acid'], bins = 15)
axes[0][3].hist(scaled_df['residual sugar'], bins = 15)
axes[1][0].hist(scaled_df['chlorides'], bins = 15)
axes[1][1].hist(scaled_df['free sulfur dioxide'], bins = 15)
axes[1][2].hist(scaled_df['total sulfur dioxide'], bins = 15)
axes[1][3].hist(scaled_df['density'], bins = 15)
axes[2][0].hist(scaled_df['pH'], bins = 15)
axes[2][1].hist(scaled_df['sulphates'], bins = 15)
axes[2][2].hist(scaled_df['alcohol'], bins = 15);

# %%
fig, axes = plt.subplots(3, 4, figsize = (16, 12))
plt.subplots_adjust(wspace = 0.25)
sns.kdeplot(scaled_df['fixed acidity'], fill = True, bw_method = 0.4, ax = axes[0][0])
axes[0][0].set_xlabel("Fixed Acidity",fontsize = 13)
axes[0][0].set_ylabel("Density", fontsize = 13)
sns.kdeplot(scaled_df['volatile acidity'], fill = True, bw_method = 0.5, ax = axes[0][1])
axes[0][1].set_xlabel("Volatile Acidity",fontsize = 13)
axes[0][1].set_ylabel("Density", fontsize = 13)
sns.kdeplot(scaled_df['citric acid'], fill = True, bw_method = 0.5, ax = axes[0][2])
axes[0][2].set_xlabel("Citric Acid",fontsize = 13)
axes[0][2].set_ylabel("Density", fontsize = 13)
sns.kdeplot(scaled_df['residual sugar'], fill = True, bw_method = 0.4, ax = axes[0][3])
axes[0][3].set_xlabel("Residual Sugar",fontsize = 13)
axes[0][3].set_ylabel("Density", fontsize = 13)
sns.kdeplot(scaled_df['chlorides'], fill = True, bw_method = 0.4, ax = axes[1][0])
axes[1][0].set_xlabel("Chlorides",fontsize = 13)
axes[1][0].set_ylabel("Density", fontsize = 13)
sns.kdeplot(scaled_df['free sulfur dioxide'], fill = True, bw_method = 0.4, ax = axes[1][1])
axes[1][1].set_xlabel("Free Sulfur Dioxide",fontsize = 13)
axes[1][1].set_ylabel("Density", fontsize = 13)
sns.kdeplot(scaled_df['total sulfur dioxide'], fill = True, bw_method = 0.3, ax = axes[1][2])
axes[1][2].set_xlabel("Total Sulfur Dioxide",fontsize = 13)
axes[1][2].set_ylabel("Density", fontsize = 13)
sns.kdeplot(scaled_df['density'], fill = True, bw_method = 0.4, ax = axes[1][3])
axes[1][3].set_xlabel("Density",fontsize = 13)
axes[1][3].set_ylabel("Density", fontsize = 13)
sns.kdeplot(scaled_df['pH'], fill = True, bw_method = 0.3, ax = axes[2][0])
axes[2][0].set_xlabel("pH",fontsize = 13)
axes[2][0].set_ylabel("Density", fontsize = 13)
sns.kdeplot(scaled_df['sulphates'], fill = True, bw_method = 0.3, ax = axes[2][1])
axes[2][1].set_xlabel("Sulphates",fontsize = 13)
axes[2][1].set_ylabel("Density", fontsize = 13)
sns.kdeplot(scaled_df['alcohol'], fill = True, bw_method = 0.5, ax = axes[2][2])
axes[2][2].set_xlabel("Alcohol",fontsize = 13)
axes[2][2].set_ylabel("Density", fontsize = 13);

# %%
# %matplotlib inline
sns.set_style('ticks')

# %%
plt.figure(figsize = (5,4))
sns.barplot(x = "quality", y = 'alcohol', data = all_df, color='steelblue', alpha = 0.7)
plt.ylabel('Alcohol', fontsize = 14)
plt.xlabel('Quality', fontsize = 14);
plt.show()

plt.figure(figsize = (5,4))
sns.barplot(x = "quality", y = 'density', data = all_df, color='steelblue', alpha = 0.7)
plt.ylabel('Density', fontsize = 14)
plt.xlabel('Quality', fontsize = 14);
plt.ylim(0.98, 1)
plt.show()

plt.figure(figsize = (5,4))
sns.barplot(x = "quality", y = 'volatile acidity', data = all_df, color='steelblue', alpha = 0.7)
plt.ylabel('volatile acidity', fontsize = 14)
plt.xlabel('Quality', fontsize = 14);
plt.show()

# %% [markdown]
# ## Intercept Model

# %%
pred = [np.around(np.mean(y_train))]*len(y_test)

# %%
# rmse
np.sqrt(mean_squared_error(y_test, pred))
# Out:
# 0.9327379053088815
